# %%
from PIL import Image, ImageFile
ImageFile.LOAD_TRUNCATED_IMAGES = True
import numpy as np
from einops import rearrange, reduce, repeat
import matplotlib.pyplot as plt
img = Image.open("TrainDataset/image/1.png").resize((352, 352), Image.BILINEAR).convert('RGB')
np_img = np.array(img)

# %%
img
# Out:
# <PIL.Image.Image image mode=RGB size=352x352 at 0x7F4FC4346F10>

# %%
test1 = rearrange(np_img, 'h w c -> w h c')
plt.imshow(test1)

# %%
compose = [img]*4
compose = np.stack(compose, axis=0)
print(compose.shape)
test_compose = rearrange(compose, 'b h w c -> h (b w) c')
# Out:
# (4, 352, 352, 3)

# %%
plt.imshow(test_compose)

# %%
test_2 = rearrange(compose, '(b1 b2) h w c -> (b1 h) (b2 w) c', b1=2)

# %%
test_2.shape
# Out:
# (704, 704, 3)

# %%
compose.shape
# Out:
# (4, 352, 352, 3)

# %%
test = compose.reshape(2*352, 2*352, -1)

# %%
plt.imshow(test)
